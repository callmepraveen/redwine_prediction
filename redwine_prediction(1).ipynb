# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


train_df = pd.read_csv('redwine.csv')
train_df.sample(5)
# Out:
#      fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 240            8.9             0.635         0.37             1.7      0.263
# 542            9.3             0.715         0.24             2.1      0.070
# 389            9.6             0.380         0.31             2.5      0.096
# 689            8.1             0.380         0.48             1.8      0.157
# 708            7.8             0.545         0.12             2.5      0.068
#
#      free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 240                  5.0                  62.0   0.9971  3.00       1.09
# 542                  5.0                  20.0   0.9966  3.12       0.59
# 389                 16.0                  49.0   0.9982  3.19       0.70
# 689                  5.0                  17.0   0.9976  3.30       1.05
# 708                 11.0                  35.0   0.9960  3.34       0.61
#
#      alcohol  quality
# 240      9.3        5
# 542      9.9        5
# 389     10.0        7
# 689      9.4        5
# 708     11.6        6

# %%
train_df.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %% [markdown]
# null returns the number of missing values in the dataset

# %%
train_df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# min       0.012000             1.000000              6.000000     0.990070
# 25%       0.070000             7.000000             22.000000     0.995600
# 50%       0.079000            14.000000             38.000000     0.996750
# 75%       0.090000            21.000000             62.000000     0.997835
# max       0.611000            72.000000            289.000000     1.003690
#
#                 pH    sulphates      alcohol      quality
# count  1599.000000  1599.000000  1599.000000  1599.000000
# mean      3.311113     0.658149    10.422983     5.636023
# std       0.154386     0.169507     1.065668     0.807569
# min       2.740000     0.330000     8.400000     3.000000
# 25%       3.210000     0.550000     9.500000     5.000000
# 50%       3.310000     0.620000    10.200000     6.000000
# 75%       3.400000     0.730000    11.100000     6.000000
# max       4.010000     2.000000    14.900000     8.000000

# %% [markdown]
# describe() method returns description of the data in the DataFrame

# %%
plt.figure(figsize=(15,15))
sns.heatmap(train_df.corr(),color = "k", annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# A heatmap is a plot of rectangular data as a color-encoded matrix. As parameter it takes a 2D dataset. That dataset can be coerced into an ndarray. This is a great way to visualize data, because it can show the relation between variabels including time.

# %%
sns.countplot(x='quality', data=train_df)
# Out:
# <AxesSubplot:xlabel='quality', ylabel='count'>

# %% [markdown]
# countplot() method is used to Show the counts of observations in each categorical bin using bars

# %%
plt.figure(figsize=(15,5))
sns.swarmplot(x= "quality", y="fixed acidity" , data = train_df) 
plt.title('fixed acidity and quality')
# Out:
# C:\Users\Praveen\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 35.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\Praveen\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 25.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# Text(0.5, 1.0, 'fixed acidity and quality')

# %% [markdown]
# A swarm plot can be drawn on its own, but it is also a good complement to a box or violin plot in cases where you want to show all observations along with some representation of the underlying distribution.

# %%
plt.figure(figsize=(15,5))
sns.boxplot(x="quality", y="fixed acidity",   data=train_df )
# Out:
# <AxesSubplot:xlabel='quality', ylabel='fixed acidity'>

# %% [markdown]
# It can sometimes be useful to display the number of observations for each group since such information is kept hidden by default

# %%
train_df.groupby('quality')['fixed acidity'].mean().plot.line()
plt.ylabel("fixed acidity")
# Out:
# Text(0, 0.5, 'fixed acidity')

# %% [raw]
# Relationship between quality and fixed acidity

# %%
plt.figure(figsize=(10,4))
sns.barplot(x="quality", y="volatile acidity",   data=train_df )
# Out:
# <AxesSubplot:xlabel='quality', ylabel='volatile acidity'>

# %% [markdown]
# Relationship between quality and volatile acidity

# %% [markdown]
# A bar plot represents an estimate of central tendency for a numeric variable with the height of each rectangle and provides some indication of the uncertainty around that estimate using error bars.

# %%
train_df.groupby('quality')['volatile acidity'].mean().plot.line()
plt.ylabel("volatile acidity")
# Out:
# Text(0, 0.5, 'volatile acidity')

# %%
plt.figure(figsize=(10,4))
sns.barplot(x="quality", y="sulphates",   data=train_df )
# Out:
# <AxesSubplot:xlabel='quality', ylabel='sulphates'>

# %% [markdown]
# Relationship between quality and sulphates

# %%
train_df.groupby('quality')['sulphates'].mean().plot.line()
plt.ylabel("sulphates")
# Out:
# Text(0, 0.5, 'sulphates')

# %%
sns.boxplot(x="quality", y="sulphates",   data=train_df )
# Out:
# <AxesSubplot:xlabel='quality', ylabel='sulphates'>

# %%
sns.boxplot(x="quality", y="pH",   data=train_df )
# Out:
# <AxesSubplot:xlabel='quality', ylabel='pH'>

# %%
train_df.groupby('quality')['pH'].mean().plot.line()
plt.ylabel("pH")
# Out:
# Text(0, 0.5, 'pH')

# %% [markdown]
# Relationship between quality and pH

# %%
sns.lmplot(x="fixed acidity", y="pH", data=train_df)

# %% [markdown]
# Relationship between fixed acidity and pH

# %% [markdown]
# Seaborn's lmplot is a 2D scatterplot with an optional overlaid regression line. This is useful for comparing numeric variables. Logistic regression for binary classification is also supported with lmplot .

# %%
sns.lmplot(y="fixed acidity", x="citric acid", data=train_df)

# %% [markdown]
# Relationship between fixed acidity and cirtric acid

# %% [markdown]
# categorising wine quality

# %%
reviews = []
for i in train_df['quality']:
    if i >= 1 and i <= 3:
        reviews.append('1')
    elif i >= 4 and i <= 7:
        reviews.append('2')
    elif i >= 8 and i <= 10:
        reviews.append('3')
train_df['Reviews'] = reviews
trainX = train_df.drop(['quality', 'Reviews'] , axis = 1)
trainy = train_df['Reviews']

# %% [markdown]
#  Different Classifier

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
# %matplotlib inline

# %% [markdown]
# Standardize the Data

# %%
scaler = StandardScaler()
X_train, X_test, y_train, y_test = train_test_split(trainX, trainy, test_size = 0.2, random_state = 42)
X_train = scaler.fit_transform(X_train)
X_test = scaler.fit_transform(X_test)
score = {}

# %% [markdown]
# RandomForestClassifier

# %%
rfc = RandomForestClassifier(n_estimators=100)
rfc.fit(X_train, y_train)
predicted_rfc = rfc.predict(X_test)
print(classification_report(y_test, predicted_rfc))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.00      0.00      0.00         1
#            2       0.98      1.00      0.99       314
#            3       0.00      0.00      0.00         5
#
#     accuracy                           0.98       320
#    macro avg       0.33      0.33      0.33       320
# weighted avg       0.96      0.98      0.97       320
# C:\Users\Praveen\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Praveen\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Praveen\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
rfc_conf_matrix = confusion_matrix(y_test, predicted_rfc)
rfc_acc_score = accuracy_score(y_test, predicted_rfc)
print(rfc_conf_matrix)
print(rfc_acc_score*100)
score.update({'Random_forest_classifier': rfc_acc_score*100})
# Out:
# [[  0   1   0]
#  [  0 314   0]
#  [  0   5   0]]
# 98.125

# %% [markdown]
# LogisticRegression

# %%
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression()
lr.fit(X_train, y_train)
predicted_lr = lr.predict(X_test)
print(classification_report(y_test, predicted_lr))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.00      0.00      0.00         1
#            2       0.98      1.00      0.99       314
#            3       0.00      0.00      0.00         5
#
#     accuracy                           0.98       320
#    macro avg       0.33      0.33      0.33       320
# weighted avg       0.96      0.98      0.97       320
# C:\Users\Praveen\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Praveen\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Praveen\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
lr_conf_matrix = confusion_matrix(y_test, predicted_lr)
lr_acc_score = accuracy_score(y_test, predicted_lr)
print(lr_conf_matrix)
print(lr_acc_score*100)
score.update({'logistic_regressor': lr_acc_score*100})
# Out:
# [[  0   1   0]
#  [  0 314   0]
#  [  0   5   0]]
# 98.125

# %% [markdown]
# SVC

# %%
svc =  SVC()
svc.fit(X_train, y_train)
predicted_svc = svc.predict(X_test)
print(classification_report(y_test, predicted_svc))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.00      0.00      0.00         1
#            2       0.98      1.00      0.99       314
#            3       0.00      0.00      0.00         5
#
#     accuracy                           0.98       320
#    macro avg       0.33      0.33      0.33       320
# weighted avg       0.96      0.98      0.97       320
# C:\Users\Praveen\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Praveen\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Praveen\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
svc_conf_matrix = confusion_matrix(y_test, predicted_svc)
svc_acc_score = accuracy_score(y_test, predicted_svc)
print(svc_conf_matrix)
print(svc_acc_score*100)
score.update({'SVC': svc_acc_score*100})
# Out:
# [[  0   1   0]
#  [  0 314   0]
#  [  0   5   0]]
# 98.125

# %% [markdown]
# Decision Tree Classifier

# %%
dt = DecisionTreeClassifier()
dt.fit(X_train,y_train)
predicted_dt = dt.predict(X_test)
print(classification_report(y_test, predicted_dt))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.00      0.00      0.00         1
#            2       0.98      0.96      0.97       314
#            3       0.00      0.00      0.00         5
#
#     accuracy                           0.94       320
#    macro avg       0.33      0.32      0.32       320
# weighted avg       0.96      0.94      0.95       320

# %%
dt_conf_matrix = confusion_matrix(y_test, predicted_dt)
dt_acc_score = accuracy_score(y_test, predicted_dt)
print(dt_conf_matrix)
print(dt_acc_score*100)
score.update({'DecisionTreeClassifier': dt_acc_score*100})
# Out:
# [[  0   1   0]
#  [  3 302   9]
#  [  0   5   0]]
# 94.375

# %% [markdown]
# GaussianNB

# %%
gb = GaussianNB()
gb.fit(X_train,y_train)
predicted_gb = gb.predict(X_test)
print(classification_report(y_test, predicted_gb))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.00      0.00      0.00         1
#            2       0.98      0.97      0.98       314
#            3       0.17      0.20      0.18         5
#
#     accuracy                           0.95       320
#    macro avg       0.38      0.39      0.39       320
# weighted avg       0.97      0.95      0.96       320

# %%
gb_conf_matrix = confusion_matrix(y_test, predicted_gb)
gb_acc_score = accuracy_score(y_test, predicted_gb)
print(gb_conf_matrix)
print(gb_acc_score*100)
score.update({'GaussianNB': gb_acc_score*100})
# Out:
# [[  0   1   0]
#  [  5 304   5]
#  [  0   4   1]]
# 95.3125

# %%
model_acc = pd.DataFrame()
model_acc['Models'] = score.keys() 
model_acc['Accuracy'] = score.values()
model_acc
# Out:
#                      Models  Accuracy
# 0  Random_forest_classifier   98.1250
# 1        logistic_regressor   98.1250
# 2                       SVC   98.1250
# 3    DecisionTreeClassifier   94.3750
# 4                GaussianNB   95.3125

# %%
from matplotlib.pyplot import xticks
sns.lineplot(x='Models', y='Accuracy',data=model_acc)
xticks(rotation=90)
# Out:
# ([0, 1, 2, 3, 4],
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %% [markdown]
# From the above accuracy comparison graph we get to know Random forest classifier,logestic regressor,svc have 98% accuracy.
